# %%
#### Create new package files (if needed)

# usethis::create_package("myrutils")
# setwd("myrutils")
# usethis::use_r("index")
# setwd("../")

# %% [markdown]
# ### Document, build, and check R package

# %%
setwd("myrutils")
devtools::document()
devtools::check()
devtools::build()
setwd("../")

# Copy a built package from the source directory to the destination directory
# file.copy(from = "myrutils_0.1.0.tar.gz", to = "../../docs/pyr")
# Out:
# ℹ Updating myrutils documentation
# ℹ Setting Config/roxygen2/version to "8.0.0"
# ℹ Loading myrutils
# Writing plot_theme.Rd
# ══ Building ════════════════════════════════════════════════════════════════════
# Setting env vars:
# • CFLAGS    : -Wall -pedantic -fdiagnostics-color=always
# • CXXFLAGS  : -Wall -pedantic -fdiagnostics-color=always
# • CXX11FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX14FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX17FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX20FLAGS: -Wall -pedantic -fdiagnostics-color=always
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-workspace\resources\R\pkgs\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
#
# ══ Checking ════════════════════════════════════════════════════════════════════
# Setting env vars:
# • _R_CHECK_CRAN_INCOMING_REMOTE_               : FALSE
# • _R_CHECK_CRAN_INCOMING_                      : FALSE
# • _R_CHECK_FORCE_SUGGESTS_                     : FALSE
# • _R_CHECK_PACKAGES_USED_IGNORE_UNUSED_IMPORTS_: FALSE
# • NOT_CRAN                                     : true
# ── R CMD check ─────────────────────────────────────────────────────────────────
# * using log directory 'C:/Users/jayan/AppData/Local/Temp/RtmpKY9IQg/file27443f2b6b72/myrutils.Rcheck'
# * using R version 4.6.0 (2026-04-24 ucrt)
# * using platform: x86_64-w64-mingw32
# * R was compiled by
#     gcc.exe (GCC) 14.3.0
#     GNU Fortran (GCC) 14.3.0
# * running under: Windows 11 x64 (build 26200)
# * using session charset: UTF-8
# * current time: 2026-05-06 15:37:55 UTC
# * using options '--no-manual --as-cran'
# * checking for file 'myrutils/DESCRIPTION' ... OK
# * this is package 'myrutils' version '0.1.0'
# * package encoding: UTF-8
# * checking package namespace information ... OK
# * checking package dependencies ... OK
# * checking if this is a source package ... OK
# * checking if there is a namespace ... OK
# * checking for executable files ... OK
# * checking for hidden files and directories ... OK
# * checking for portable file names ... OK
# * checking serialization versions ... OK
# * checking whether package 'myrutils' can be installed ... OK
# * checking installed package size ... OK
# * checking package directory ... OK
# * checking for future file timestamps ... OK
# * checking DESCRIPTION meta-information ... NOTE
# License components which are templates and need '+ file LICENSE':
#   MIT
# * checking top-level files ... OK
# * checking for left-over files ... OK
# * checking index information ... OK
# * checking package subdirectories ... OK
# * checking code files for non-ASCII characters ... OK
# * checking R files for syntax errors ... OK
# * checking whether the package can be loaded ... OK
# * checking whether the package can be loaded with stated dependencies ... OK
# * checking whether the package can be unloaded cleanly ... OK
# * checking whether the namespace can be loaded with stated dependencies ... OK
# * checking whether the namespace can be unloaded cleanly ... OK
# * checking loading without being on the library search path ... OK
# * checking dependencies in R code ... OK
# * checking S3 generic/method consistency ... OK
# * checking replacement functions ... OK
# * checking foreign function calls ... OK
# * checking R code for possible problems ... NOTE
# get_contrasts: no visible binding for global variable 'estimate'
# get_contrasts: no visible binding for global variable 'p.value'
# get_contrasts: no visible binding for global variable 'df'
# get_contrasts: no visible binding for global variable 't.ratio'
# get_likert_plot: no visible binding for global variable 'Frequency'
# get_likert_plot: no visible binding for global variable 'Ratio'
# get_likert_plot: no visible binding for global variable 'Marker'
# get_likert_plot: no visible binding for global variable 'VariableY'
# get_lm_writeup: no visible global function definition for 'filter'
# save_table: no visible global function definition for 'capture.output'
# Undefined global functions or variables:
#   Frequency Marker Ratio VariableY capture.output df estimate filter
#   p.value t.ratio
# Consider adding
#   importFrom("stats", "df", "filter")
#   importFrom("utils", "capture.output")
# to your NAMESPACE file.
# * checking Rd files ... OK
# * checking Rd metadata ... OK
# * checking Rd line widths ... OK
# * checking Rd cross-references ... OK
# * checking for missing documentation entries ... OK
# * checking for code/documentation mismatches ... OK
# * checking Rd \usage sections ... OK
# * checking Rd contents ... OK
# * checking for unstated dependencies in examples ... OK
# * checking examples ... OK
# * checking for non-standard things in the check directory ... OK
# * checking for detritus in the temp directory ... OK
# * DONE
#
# Status: 2 NOTEs
# See
#   'C:/Users/jayan/AppData/Local/Temp/RtmpKY9IQg/file27443f2b6b72/myrutils.Rcheck/00check.log'
# for details.
# ERROR: Unknown command "TMPDIR=C:/Users/jayan/AppData/Local/Temp/Rtmp2pq0b2/filef481de08f4". Did you mean command "install"?
# Warning message:
# In system2("quarto", "-V", stdout = TRUE, env = paste0("TMPDIR=",  :
#   running command '"quarto" TMPDIR=C:/Users/jayan/AppData/Local/Temp/Rtmp2pq0b2/filef481de08f4 -V' had status 1
# ── R CMD check results ───────────────────────────────────── myrutils 0.1.0 ────
# Duration: 29.4s
#
# ❯ checking DESCRIPTION meta-information ... NOTE
#   License components which are templates and need '+ file LICENSE':
#     MIT
#
# ❯ checking R code for possible problems ... NOTE
#   get_contrasts: no visible binding for global variable 'estimate'
#   get_contrasts: no visible binding for global variable 'p.value'
#   get_contrasts: no visible binding for global variable 'df'
#   get_contrasts: no visible binding for global variable 't.ratio'
#   get_likert_plot: no visible binding for global variable 'Frequency'
#   get_likert_plot: no visible binding for global variable 'Ratio'
#   get_likert_plot: no visible binding for global variable 'Marker'
#   get_likert_plot: no visible binding for global variable 'VariableY'
#   get_lm_writeup: no visible global function definition for 'filter'
#   save_table: no visible global function definition for 'capture.output'
#   Undefined global functions or variables:
#     Frequency Marker Ratio VariableY capture.output df estimate filter
#     p.value t.ratio
#   Consider adding
#     importFrom("stats", "df", "filter")
#     importFrom("utils", "capture.output")
#   to your NAMESPACE file.
#
# 0 errors ✔ | 0 warnings ✔ | 2 notes ✖
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-workspace\resources\R\pkgs\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
# [1] "C:/Users/jayan/Documents/create-workspace/resources/R/pkgs/myrutils_0.1.0.tar.gz"

# %%
reset_packages()

# %% [markdown]
# ### Load package from tar.gz file and test

# %%
devtools::install("myrutils")
# Out:
# ── pak::local_install_deps() ───────────────────────────────────────────────────
# ✔ Updated metadata database: 6.56 MB in 15 files.
#
#
#
# ℹ Updating metadata database
#
# ✔ Updating metadata database ... done
#
#
#
#
#
# → Will download 1 package with unknown size.
#
# ℹ No downloads are needed
#
# ✔ 82 deps: kept 82 [27s]
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-workspace\resources\R\pkgs\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
#
# ── R CMD INSTALL ───────────────────────────────────────────────────────────────
# Running "C:/Users/jayan/scoop/apps/r/current/bin/x64/Rcmd.exe" INSTALL \
#   "C:\Users\jayan\AppData\Local\Temp\RtmpKY9IQg/myrutils_0.1.0.tar.gz" \
#   --install-tests
# * installing to library 'C:/Users/jayan/scoop/persist/r/site-library'
# * installing *source* package 'myrutils' ...
# ** this is package 'myrutils' version '0.1.0'
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (myrutils)

# %%
library(myrutils)

# %%
packages <- c(
    "pwr"
)
packages_check(packages)
# Out:
# Loading required package: pwr
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "there is no package called 'pwr'"
# Installing package into 'C:/Users/jayan/scoop/persist/r/site-library'
# (as 'lib' is unspecified)
# package 'pwr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\jayan\AppData\Local\Temp\RtmpKY9IQg\downloaded_packages
# [[1]]
# [1] "pwr"       "myrutils"  "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"

# %%
# Cohen's effect sizes small=.02, medium=.15, large=.35 (Cohen, J. (1988). Statistical power analysis for the behavioral sciences (2nd ed.). Hillsdale, NJ: Lawrence Erlbaum)

# u is the number of coefficients in the model (i.e., number of independent + interaction variables + 1 for cutoff - b0) Therefore, u >= 2

# u = 3 because b0 + ConditionC + CovariateC (e.g., ManufacturabilityC)
pwr.f2.test(
    u = 2,
    f2 = cohen.ES(
        test = "f2", # c("p", "t", "r", "anov", "chisq", "f2")
        size = "medium" # c("small", "medium", "large")
    )$effect.size,
    sig.level = 0.05,
    power = 0.8
)
# sample size = u + roundup(v) + 1

pwr.t.test(
    d = cohen.ES(
        test = "t", # c("p", "t", "r", "anov", "chisq", "f2")
        size = "medium" # c("small", "medium", "large")
    )$effect.size,
    sig.level = 0.05,
    power = 0.8,
    type = "one.sample"
)
# sample size = n
# Out:
#      Multiple regression power calculation
#
#               u = 2
#               v = 64.31932
#              f2 = 0.15
#       sig.level = 0.05
#           power = 0.8
#      One-sample t test power calculation
#
#               n = 33.36713
#               d = 0.5
#       sig.level = 0.05
#           power = 0.8
#     alternative = two.sided
